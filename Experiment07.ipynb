# %% [markdown]
# Aim: Implement RNN for Sentiment Analysis on movie reviews.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
max_features = 10000
print("Loading data..")
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=max_features)
# Out:
# Loading data..

# %%
max_len = 100
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(input_dim=max_features, output_dim=32, input_length=max_len))
model.add(SimpleRNN(32))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print("Training model:")
history = model.fit(X_train, y_train,epochs=7,batch_size=128,validation_split=0.2)
# Out:
# Training model:
# Epoch 1/7
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.7126 - loss: 0.5333 - val_accuracy: 0.8246 - val_loss: 0.3942
# Epoch 2/7
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8646 - loss: 0.3302 - val_accuracy: 0.8390 - val_loss: 0.3731
# Epoch 3/7
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9096 - loss: 0.2350 - val_accuracy: 0.8336 - val_loss: 0.3778
# Epoch 4/7
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9385 - loss: 0.1738 - val_accuracy: 0.8342 - val_loss: 0.3938
# Epoch 5/7
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9622 - loss: 0.1185 - val_accuracy: 0.8288 - val_loss: 0.4953
# Epoch 6/7
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9793 - loss: 0.0735 - val_accuracy: 0.8232 - val_loss: 0.4868
# Epoch 7/7
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9821 - loss: 0.0595 - val_accuracy: 0.8204 - val_loss: 0.5587

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8222 - loss: 0.5722
# Test Accuracy: 82.22%
